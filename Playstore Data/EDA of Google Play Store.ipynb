# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\soume\iNeuron Resources\Doubt Clearing\6th Oct FSDS bootcamp\google_cleaned.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3.6       100  Free    0.0       Everyone
# 10837     NaN        3   9.5      1000  Free    0.0       Everyone
# 10838     4.5      114   NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.sample(5)
# Out:
#                                    App            Category  Rating  Reviews  \
# 10492         Cake Shop - Kids Cooking              FAMILY     4.3    30668
# 3379                Microsoft Launcher     PERSONALIZATION     4.6   649568
# 2788     Savory - Deals,Freebies,Sales            SHOPPING     4.4     2375
# 1517                     Lamp detector  LIBRARIES_AND_DEMO     NaN        5
# 5527   Megatramp - a Story of Success!              FAMILY     4.3   322976
#
#        Size  Installs  Type  Price Content Rating               Genres  \
# 10492  33.0   5000000  Free    0.0       Everyone  Casual;Pretend Play
# 3379   26.0  10000000  Free    0.0       Everyone      Personalization
# 2788    1.1    100000  Free    0.0       Everyone             Shopping
# 1517    1.8      1000  Free    0.0       Everyone     Libraries & Demo
# 5527    NaN   5000000  Free    0.0           Teen           Simulation
#
#       Last Updated         Current Ver   Android Ver  day  month  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews         Size      Installs         Price  \
# count  9366.000000  1.084000e+04  9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05    21.506534  1.546434e+07      1.027368
# std       0.515219  2.927761e+06    22.596021  8.502936e+07     15.949703
# min       1.000000  0.000000e+00     0.010000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01     4.900000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03    13.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04    30.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09    400.000000
#
#                 day         month          year
# count  10840.000000  10840.000000  10840.000000
# mean      15.609041      6.422325   2017.399723
# std        9.561621      2.578388      1.100914
# min        1.000000      1.000000   2010.000000
# 25%        6.000000      5.000000   2017.000000
# ...

# %%
df.describe(include='all')
# Out:
#            App Category       Rating       Reviews         Size      Installs  \
# count    10840    10840  9366.000000  1.084000e+04  9145.000000  1.084000e+04
# unique    9659       33          NaN           NaN          NaN           NaN
# top     ROBLOX   FAMILY          NaN           NaN          NaN           NaN
# freq         9     1972          NaN           NaN          NaN           NaN
# mean       NaN      NaN     4.191757  4.441529e+05    21.506534  1.546434e+07
# std        NaN      NaN     0.515219  2.927761e+06    22.596021  8.502936e+07
# min        NaN      NaN     1.000000  0.000000e+00     0.010000  0.000000e+00
# 25%        NaN      NaN     4.000000  3.800000e+01     4.900000  1.000000e+03
# 50%        NaN      NaN     4.300000  2.094000e+03    13.000000  1.000000e+05
# 75%        NaN      NaN     4.500000  5.477550e+04    30.000000  5.000000e+06
# max        NaN      NaN     5.000000  7.815831e+07   100.000000  1.000000e+09
#
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# day                  0
# month                0
# year                 0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Exporing the data

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype!='O']
categorical_features=[feature for feature in df.columns if df[feature].dtypes=='O']

# %%
df[numeric_features]
# Out:
#        Rating  Reviews  Size  Installs  Price  day  month  year
# 0         4.1      159  19.0     10000    0.0    7      1  2018
# 1         3.9      967  14.0    500000    0.0   15      1  2018
# 2         4.7    87510   8.7   5000000    0.0    1      8  2018
# 3         4.5   215644  25.0  50000000    0.0    8      6  2018
# 4         4.3      967   2.8    100000    0.0   20      6  2018
# ...       ...      ...   ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53.0      5000    0.0   25      7  2017
# 10836     5.0        4   3.6       100    0.0    6      7  2018
# 10837     NaN        3   9.5      1000    0.0   20      1  2017
# 10838     4.5      114   NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19.0  10000000    0.0   25      7  2018
#
# [10840 rows x 8 columns]

# %%
df[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9659, dtype: int64

# %%
df["App"].value_counts(normalize=True)
# Out:
# ROBLOX                                                0.000830
# CBS Sports App - Scores, News, Stats & Watch Live     0.000738
# ESPN                                                  0.000646
# Duolingo: Learn Languages Free                        0.000646
# Candy Crush Saga                                      0.000646
#                                                         ...
# Meet U - Get Friends for Snapchat, Kik & Instagram    0.000092
# U-Report                                              0.000092
# U of I Community Credit Union                         0.000092
# Waiting For U Launcher Theme                          0.000092
# iHoroscope - 2018 Daily Horoscope & Astrology         0.000092
# Name: App, Length: 9659, dtype: float64

# %%
## Calculating percentages of feature
df["App"].value_counts(normalize=True)*100
# Out:
# ROBLOX                                                0.083026
# CBS Sports App - Scores, News, Stats & Watch Live     0.073801
# ESPN                                                  0.064576
# Duolingo: Learn Languages Free                        0.064576
# Candy Crush Saga                                      0.064576
#                                                         ...
# Meet U - Get Friends for Snapchat, Kik & Instagram    0.009225
# U-Report                                              0.009225
# U of I Community Credit Union                         0.009225
# Waiting For U Launcher Theme                          0.009225
# iHoroscope - 2018 Daily Horoscope & Astrology         0.009225
# Name: App, Length: 9659, dtype: float64

# %%
len(df["App"].value_counts())
# Out:
# 9659

# %%
num_df=df[numeric_features]
num_df
# Out:
#        Rating  Reviews  Size  Installs  Price  day  month  year
# 0         4.1      159  19.0     10000    0.0    7      1  2018
# 1         3.9      967  14.0    500000    0.0   15      1  2018
# 2         4.7    87510   8.7   5000000    0.0    1      8  2018
# 3         4.5   215644  25.0  50000000    0.0    8      6  2018
# 4         4.3      967   2.8    100000    0.0   20      6  2018
# ...       ...      ...   ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53.0      5000    0.0   25      7  2017
# 10836     5.0        4   3.6       100    0.0    6      7  2018
# 10837     NaN        3   9.5      1000    0.0   20      1  2017
# 10838     4.5      114   NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19.0  10000000    0.0   25      7  2018
#
# [10840 rows x 8 columns]

# %%
cat_df=df[categorical_features]

# %%
# Check the ditribution of the numerix_variable
sns.kdeplot(num_df['Rating'],color='b')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True,color='m')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.boxplot(x=df[numeric_features[i]],color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# ## observations

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
cat_df['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
sns.countplot(cat_df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(cat_df['Content Rating'])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
# categorical columns
plt.figure(figsize=(60,50))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=50, fontweight='bold', alpha=0.8, y=1.)
category=['Type','Content Rating','Category']
for i in range(0, len(category)):
    plt.subplot(3, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=56)
    plt.tight_layout()

# %% [markdown]
# ## Which one will be more popular category?

# %%
cat_df['Category'].value_counts().plot.pie(figsize=(20,30),autopct='%1.1f')
# Out:
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# ## Top 10 app categories

# %%
category=pd.DataFrame(cat_df["Category"].value_counts())

# %%
category.head(10)
# Out:
#                  Category
# FAMILY               1972
# GAME                 1144
# TOOLS                 843
# MEDICAL               463
# BUSINESS              460
# PRODUCTIVITY          424
# PERSONALIZATION       392
# COMMUNICATION         387
# SPORTS                384
# LIFESTYLE             382

# %%
category.rename(columns={"Category":"Count"},inplace=True)

# %%
category.head(10)
# Out:
#                  Count
# FAMILY            1972
# GAME              1144
# TOOLS              843
# MEDICAL            463
# BUSINESS           460
# PRODUCTIVITY       424
# PERSONALIZATION    392
# COMMUNICATION      387
# SPORTS             384
# LIFESTYLE          382

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=category.index[:10],y="Count",data=category[:10])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
plt.figure(figsize=(20,20))
sns.countplot(category['Count'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='count'>

# %% [markdown]
# ## Which category has largest number of installation?

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1=df.groupby("Category")['Installs'].sum().nlargest(10).plot.bar()

# %%
df1=df.groupby("Category")['Installs'].sum().nlargest(10).plot(kind='pie')
